# %% [markdown]
# # Implement a two class neural network with a hidden layer on any standard dataset.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data(path = 'mnist_db')
# Cast the records into float values
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# normalize image pixel values by dividing
# by 255 gray_scale
gray_scale=  255 
x_train /= gray_scale 
x_test /= gray_scale 
print("Feature matrix:", x_train.shape)
print("Target matrix:", x_test.shape)
print("Feature matrix:", y_train.shape)
print("Target matrix:", y_test.shape)
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28, 28),
        aspect='auto')
k += 1
plt.show()
model = Sequential([
# reshape 28 row * 28 column data to 28*28 rows
Flatten(input_shape=(28, 28)),
# dense layer 1
Dense(256, activation='sigmoid'),
# dense layer 2
Dense(128, activation='sigmoid'),
# output layer
Dense(10, activation='sigmoid'),
])
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10,
batch_size=2000,
validation_split=0.2)
results = model.evaluate(x_test, y_test, verbose = 0)
print('test loss, test acc:', results)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)
# C:\Python\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.2523 - loss: 2.2497 - val_accuracy: 0.7477 - val_loss: 1.7464
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.7232 - loss: 1.5789 - val_accuracy: 0.7999 - val_loss: 1.0751
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8004 - loss: 0.9852 - val_accuracy: 0.8577 - val_loss: 0.7000
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8526 - loss: 0.6751 - val_accuracy: 0.8830 - val_loss: 0.5139
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8798 - loss: 0.5120 - val_accuracy: 0.8979 - val_loss: 0.4190
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8914 - loss: 0.4286 - val_accuracy: 0.9064 - val_loss: 0.3652
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9010 - loss: 0.3759 - val_accuracy: 0.9137 - val_loss: 0.3280
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9092 - loss: 0.3373 - val_accuracy: 0.9198 - val_loss: 0.3029
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9131 - loss: 0.3156 - val_accuracy: 0.9237 - val_loss: 0.2828
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9177 - loss: 0.2941 - val_accuracy: 0.9256 - val_loss: 0.2679
# test loss, test acc: [0.27423590421676636, 0.9230999946594238]
